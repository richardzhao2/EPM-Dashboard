# %%
import pandas as pd
import pickle


coll = []

for x in range(1, 5):
    coll.append( pickle.load( open( "SPORTVU PY/NBA_LG_FINAL_SEQUENCE_OPTICAL$2016102505_Q"+str(x)+".p", "rb" ) ))
coll
# Out:
# [[{'game-clock': '720.00',
#    'game-event-id': '',
#    'locations': '-1,-1,47.13248,28.14078,4.80829;5,214152,52.06204,36.55583,0;5,253997,48.19851,14.86676,0;5,395374,59.89999,30.06305,0;5,551768,59.73518,30.4817,0;5,552806,48.85235,24.29689,0;18,172890,47.43618,36.39903,0;18,263220,45.68554,26.50675,0;18,276755,46.63328,14.68745,0;18,399612,11.54205,26.79228,0;18,877869,37.57692,24.91517,0',
#    'shot-clock': '24.00',
#    'time': '1477438579336'},
#   {'game-clock': '720.00',
#    'game-event-id': '',
#    'locations': '-1,-1,47.02735,28.1051,4.77021;5,214152,51.98853,36.51799,0;5,253997,48.21179,14.90437,0;5,395374,59.87765,30.07992,0;5,551768,59.76784,30.39574,0;5,552806,48.82836,24.24862,0;18,172890,47.43423,36.38794,0;18,263220,45.694,26.51621,0;18,276755,46.66147,14.67148,0;18,399612,11.49175,26.84274,0;18,877869,37.59448,24.916,0',
#    'shot-clock': '24.00',
#    'time': '1477438579376'},
#   {'game-clock': '720.00',
#    'game-event-id': '',
# ...
