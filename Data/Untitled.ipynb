# %%
import pandas as pd

# %%
games = pd.read_csv('../App/server/shotlog.csv')
games.head()
# Out:
#     GAME_ID  PERSON_ID     TEAM_ID  SHOT_ORDER  SV_GAME_ID  SV_PLAYER_ID  \
# 0  21600014     202693  1610612764           1  2016102701          4894
# 1  21600014     202693  1610612764           2  2016102701          4894
# 2  21600014     202693  1610612764           3  2016102701          4894
# 3  21600014     202693  1610612764           4  2016102701          4894
# 4  21600014     202693  1610612764           5  2016102701          4894
#
#    SV_TEAM_ID SHOT_RESULT  PERIOD  GAME_CLOCK ...   DRIBBLES  SHOT_DIST  \
# 0          27      missed       1        7050 ...          0      12.46
# 1          27      missed       1        6910 ...          0       3.48
# 2          27        made       1        6050 ...          1       9.57
# 3          27        made       1        5480 ...          0      12.48
# 4          27        made       1        5150 ...          2      19.45
#
#    TOUCH_TIME  CLOSE_DEF_PERSON_ID CLOSE_DEF_SV_PLAYER_ID  CLOSE_DEF_DIST  \
# ...

# %%
current = games[games['SV_GAME_ID'] == 2016102505]
current.sort_values(['GAME_CLOCK'], ascending=[True])
current.to_csv('game.csv')
