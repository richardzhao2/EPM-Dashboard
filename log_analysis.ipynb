# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Loading in Data...")

shotFile = "Basketball Data/NBAPlayerTrackingData_2014-17/2016-17_nba_shot_log.csv"
shot_df = pd.read_csv(shotFile)

possessFile = "Basketball Data/NBAPlayerTrackingData_2014-17/2016-17_nba_possession_log.csv"
possess_df = pd.read_csv(possessFile)

passFile = "Basketball Data/NBAPlayerTrackingData_2014-17/2016-17_nba_pass_log.csv"
pass_df = pd.read_csv(passFile)

svFile = "Basketball Data/NBAPlayerTrackingData_2014-17/2016-17_nba_sv_box_scores.csv"
sv_df = pd.read_csv(svFile)

print("Done!")
# Out:
# Loading in Data...
# Done!

# %%
print("Compiling Headers...")
print()

print("Shot Log:")
for i in range(len(list(shot_df))):
    head = list(shot_df)[i]
    if i == 0:
        shot_df.rename(columns={head: 'GAME_ID'}, inplace=True)
    print(head)
print()

print("Possession Log:")
for j in range(len(list(possess_df))):
    head = list(possess_df)[j]
    if j == 0:
        possess_df.rename(columns={head: 'GAME_ID'}, inplace=True)
    print(head)
print()

print("Pass Log:")
for k in range(len(list(pass_df))):
    head = list(pass_df)[k]
    if k == 0:
        pass_df.rename(columns={head: 'GAME_ID'}, inplace=True)
    print(head)
print()

print("SportVU Log:")
for l in range(len(list(sv_df))):
    head = list(sv_df)[l]
    if l == 0:
        sv_df.rename(columns={head: 'GAME_ID'}, inplace=True)
    print(head)
print()

print("Done!")
# Out:
# Compiling Headers...
#
# Shot Log:
# ﻿GAME_ID
# PERSON_ID
# TEAM_ID
# SHOT_ORDER
# SV_GAME_ID
# SV_PLAYER_ID
# SV_TEAM_ID
# SHOT_RESULT
# PERIOD
# GAME_CLOCK
# WALL_CLOCK
# DRIBBLES
# SHOT_DIST
# TOUCH_TIME
# CLOSE_DEF_PERSON_ID
# CLOSE_DEF_SV_PLAYER_ID
# CLOSE_DEF_DIST
# PTS_TYPE
# FGM
# FGA
# PTS
#
# Possession Log:
# ﻿GAME_ID
# POSSESSION_ID
# TEAM_ID
# SV_GAME_ID
# SV_TEAM_ID
# PERIOD
# PTS
# RESULT
# DRIBBLES
# PASSES
# TOUCHES
# GAME_CLOCK_START
# GAME_CLOCK_END
# POSSESSION_LENGTH
#
# Pass Log:
# ﻿GAME_ID
# PERSON_ID
# TEAM_ID
# SV_GAME_ID
# SV_PLAYER_ID
# PERIOD
# PASS_TIME
# GAME_CLOCK
# SHOT_CLOCK
# X
# Y
# PLAYER_TYPE
# PLAYER_TYPE_ID
#
# SportVU Log:
# ﻿GAME_ID
# PERSON_ID
# TEAM_ID
# SV_GAME_ID
# SV_PLAYER_ID
# SV_TEAM_ID
# LEAGUE_ID
# SEASON_ID
# DATE_EST
# LOCATION
# OUTCOME
# VS_TEAM_ID
# DIST_RUN_METERS
# DIST_RUN_FEET
# DIST_RUN_OFF_METERS
# DIST_RUN_OFF_FEET
# DIST_RUN_DEF_METERS
# DIST_RUN_DEF_FEET
# AVG_SPEED_KPH
# AVG_SPEED_MPH
# AVG_SPEED_OFF_KPH
# AVG_SPEED_OFF_MPH
# AVG_SPEED_DEF_KPH
# AVG_SPEED_DEF_MPH
# NUM_TOUCHES
# NUM_HALF_CT_TOUCHES
# AVG_SEC_PER_TCH
# NUM_TOUCHES_0_2_SECS
# NUM_TOUCHES_2_4_SECS
# NUM_TOUCHES_4_PLUS_SECS
# AVG_DRIB_PER_TCH
# NUM_TOUCHES_0_0_DRIB
# NUM_TOUCHES_1_2_DRIB
# NUM_TOUCHES_3_5_DRIB
# NUM_TOUCHES_6_PLUS_DRIB
# SHOT_DIST_0_5_FGM
# SHOT_DIST_0_5_FGA
# SHOT_DIST_5_10_FGM
# SHOT_DIST_5_10_FGA
# SHOT_DIST_0_10_FGM
# SHOT_DIST_0_10_FGA
# SHOT_DIST_10_15_FGM
# SHOT_DIST_10_15_FGA
# SHOT_DIST_15_20_FGM
# SHOT_DIST_15_20_FGA
# SHOT_DIST_20_PLUS_FGM
# SHOT_DIST_20_PLUS_FGA
# CATCH_SHOOT_DIST_10_15_FGM
# CATCH_SHOOT_DIST_10_15_FGA
# CATCH_SHOOT_DIST_15_20_FGM
# CATCH_SHOOT_DIST_15_20_FGA
# CATCH_SHOOT_DIST_20_PLUS_FGM
# CATCH_SHOOT_DIST_20_PLUS_FGA
# CATCH_SHOOT_FG3M
# CATCH_SHOOT_FG3A
# DRIB_0_0_FGM
# DRIB_0_0_FGA
# DRIB_1_2_FGM
# DRIB_1_2_FGA
# DRIB_3_4_FGM
# DRIB_3_4_FGA
# DRIB_5_PLUS_FGM
# DRIB_5_PLUS_FGA
# DRIB_0_0_FG3M
# DRIB_0_0_FG3A
# DRIB_1_2_FG3M
# DRIB_1_2_FG3A
# DRIB_3_4_FG3M
# DRIB_3_4_FG3A
# DRIB_5_PLUS_FG3M
# DRIB_5_PLUS_FG3A
# POSS_SEC_0_2_FGM
# POSS_SEC_0_2_FGA
# POSS_SEC_2_4_FGM
# POSS_SEC_2_4_FGA
# POSS_SEC_4_PLUS_FGM
# POSS_SEC_4_PLUS_FGA
# POSS_SEC_0_2_FG3M
# POSS_SEC_0_2_FG3A
# POSS_SEC_2_4_FG3M
# POSS_SEC_2_4_FG3A
# POSS_SEC_4_PLUS_FG3M
# POSS_SEC_4_PLUS_FG3A
# DEF_DIST_0_2_FGM
# DEF_DIST_0_2_FGA
# DEF_DIST_2_4_FGM
# DEF_DIST_2_4_FGA
# DEF_DIST_4_PLUS_FGM
# DEF_DIST_4_PLUS_FGA
# DEF_DIST_0_2_FG3M
# DEF_DIST_0_2_FG3A
# DEF_DIST_2_4_FG3M
# DEF_DIST_2_4_FG3A
# DEF_DIST_4_PLUS_FG3M
# DEF_DIST_4_PLUS_FG3A
# SHOT_CLK_0_6_FGM
# SHOT_CLK_0_6_FGA
# SHOT_CLK_6_12_FGM
# SHOT_CLK_6_12_FGA
# SHOT_CLK_12_18_FGM
# SHOT_CLK_12_18_FGA
# SHOT_CLK_18_24_FGM
# SHOT_CLK_18_24_FGA
# SHOT_CLK_0_6_FG3M
# SHOT_CLK_0_6_FG3A
# SHOT_CLK_6_12_FG3M
# SHOT_CLK_6_12_FG3A
# SHOT_CLK_12_18_FG3M
# SHOT_CLK_12_18_FG3A
# SHOT_CLK_18_24_FG3M
# SHOT_CLK_18_24_FG3A
# CONT_RIM_DEF_1_1_FGM
# CONT_RIM_DEF_1_1_FGA
# CONT_RIM_DEF_2_5_FGM
# CONT_RIM_DEF_2_5_FGA
# SHOT_10FT_DEF_DIST_0_2_FGM
# SHOT_10FT_DEF_DIST_0_2_FGA
# SHOT_10FT_DEF_DIST_2_4_FGM
# SHOT_10FT_DEF_DIST_2_4_FGA
# SHOT_10FT_DEF_DIST_4_PLUS_FGM
# SHOT_10FT_DEF_DIST_4_PLUS_FGA
# SHOT_10FT_DEF_DIST_0_2_FG3M
# SHOT_10FT_DEF_DIST_0_2_FG3A
# SHOT_10FT_DEF_DIST_2_4_FG3M
# SHOT_10FT_DEF_DIST_2_4_FG3A
# SHOT_10FT_DEF_DIST_4_PLUS_FG3M
# SHOT_10FT_DEF_DIST_4_PLUS_FG3A
# SHOT_10FT_DRIB_0_0_FGM
# SHOT_10FT_DRIB_0_0_FGA
# SHOT_10FT_DRIB_1_2_FGM
# SHOT_10FT_DRIB_1_2_FGA
# SHOT_10FT_DRIB_3_4_FGM
# SHOT_10FT_DRIB_3_4_FGA
# SHOT_10FT_DRIB_5_PLUS_FGM
# SHOT_10FT_DRIB_5_PLUS_FGA
# SHOT_10FT_DRIB_0_0_FG3M
# SHOT_10FT_DRIB_0_0_FG3A
# SHOT_10FT_DRIB_1_2_FG3M
# SHOT_10FT_DRIB_1_2_FG3A
# SHOT_10FT_DRIB_3_4_FG3M
# SHOT_10FT_DRIB_3_4_FG3A
# SHOT_10FT_DRIB_5_PLUS_FG3M
# SHOT_10FT_DRIB_5_PLUS_FG3A
# DEF_RIM_FGM
# DEF_RIM_FGA
# PASSES_MADE
# PASSES_RECEIVED
# OREB_AVG_DIST
# OREB_CONTEST
# OREB_UNCONTEST
# OREB_CONTEST_PCT
# OREB_CHANCES
# OREB_CHANCE_PCT
# OREB_CHANCE_DEFER
# OREB_CHANCE_PCT_ADJ
# DREB_AVG_DIST
# DREB_CONTEST
# DREB_UNCONTEST
# DREB_CONTEST_PCT
# DREB_CHANCES
# DREB_CHANCE_PCT
# DREB_CHANCE_DEFER
# DREB_CHANCE_PCT_ADJ
# REB_AVG_DIST
# REB_CONTEST
# REB_UNCONTEST
# REB_CONTEST_PCT
# REB_CHANCES
# REB_CHANCE_PCT
# REB_CHANCE_DEFER
# REB_CHANCE_PCT_ADJ
# SECONDARY_AST
# POTENTIAL_AST
# AST_POINTS_CREATED
# FT_AST
# AST_ADJ
# AST_TO_PASS_PCT
# AST_TO_PASS_PCT_ADJ
# DRIBBLES
# DRIVES
# DRIVE_POINTS
# DRIVE_FTM
# DRIVE_FTA
# DRIVE_FGM
# DRIVE_FGA
# DRIVE_PASSES
# DRIVE_AST
# DRIVE_AST_PCT
# DRIVE_TOV
# DRIVE_TOV_PCT
# DRIVE_FOULS
# ELBOW_TOUCHES
# ELBOW_TOUCH_PTS
# ELBOW_TOUCH_FTM
# ELBOW_TOUCH_FTA
# ELBOW_TOUCH_FGM
# ELBOW_TOUCH_FGA
# ELBOW_TOUCH_PASSES
# ELBOW_TOUCH_AST
# ELBOW_TOUCH_AST_PCT
# ELBOW_TOUCH_TOV
# ELBOW_TOUCH_TOV_PCT
# ELBOW_TOUCH_FOULS
# POST_TOUCHES
# POST_TOUCH_PTS
# POST_TOUCH_FTM
# POST_TOUCH_FTA
# POST_TOUCH_FGM
# POST_TOUCH_FGA
# POST_TOUCH_PASSES
# POST_TOUCH_AST
# POST_TOUCH_AST_PCT
# POST_TOUCH_TOV
# POST_TOUCH_TOV_PCT
# POST_TOUCH_FOULS
# PAINT_TOUCHES
# PAINT_TOUCH_PTS
# PAINT_TOUCH_FTM
# PAINT_TOUCH_FTA
# PAINT_TOUCH_FGM
# PAINT_TOUCH_FGA
# PAINT_TOUCH_PASSES
# PAINT_TOUCH_AST
# PAINT_TOUCH_AST_PCT
# PAINT_TOUCH_TOV
# PAINT_TOUCH_TOV_PCT
# PAINT_TOUCH_FOULS
#
# Done!

# %%
shot_df = shot_df.sort_values(['GAME_ID', 'GAME_CLOCK'], ascending=[True, False])
possess_df = possess_df.sort_values(['GAME_ID', 'GAME_CLOCK_START'], ascending=[True, True])
pass_df = pass_df.sort_values(['GAME_ID', 'GAME_CLOCK'], ascending=[True, False])
sv_df = sv_df.sort_values(['GAME_ID'], ascending=[True])
